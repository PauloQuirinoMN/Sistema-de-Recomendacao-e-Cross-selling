# %%
import pandas as pd

# %%
base_estoque = pd.read_excel("bases/bases_limpas/base_estoque_limpo.xlsx")
base_estoque

# %%
base_estoque.nunique()
# Out:
# Código Produto         32699
# Produto                32699
# Código da Marca          826
# Marca                    826
# Código da categoria      686
# Categoria                686
# Quantidade estoque      1360
# Preço de custo          5782
# dtype: int64

# %%
base_notas = pd.read_excel("bases/bases_limpas/base_vendas_limpas.xlsx")
base_notas
# Out:
#         Numero nota fiscal Data da venda  Código produto  \
# 0                   566082    17/06/2025           33932
# 1                   566082    17/06/2025           29367
# 2                   566082    17/06/2025             241
# 3                   566082    17/06/2025           32608
# 4                   566082    17/06/2025           18508
# ...                    ...           ...             ...
# 327198               16916    02/01/2025            8802
# 327199               16915    02/01/2025           21602
# 327200               16914    02/01/2025           21602
# 327201               16913    02/01/2025           36564
# 327202               16912    02/01/2025           27891
#
#                             Descrição do produto  Quantidade do produto  \
# 0                ENV 229X324 OU C/100 FILIPERSON                    2.0
# 1          GUARDANAPO SNOB FS 33X30 50F SANTHER                     5.0
# ...

# %%
base_notas.nunique()
# Out:
# Numero nota fiscal       30036
# Data da venda              134
# Código produto            8914
# Descrição do produto      8914
# Quantidade do produto      470
# Valor unitário            9529
# Preço venda               8972
# Preço de custo            3608
# Valor da nota            26110
# dtype: int64
