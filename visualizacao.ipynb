# %%
import pandas as pd

# %%
df_estoque = pd.read_excel('bases/bases_limpas/base_estoque_limpo.xlsx', index=False)
df_estoque
# Out:
#        Unnamed: 0  Código Produto                                  Produto  \
# 0               0               1     LAPIS Nº2 HB PT C/144 SERELEPE ECOLE
# 1               1               3           CANETA HIDRO PONTA FINA PT CIS
# 2               2               4                BANDEIRINHAS JUNINAS MEGA
# 3               3               5         FITA IMP EPSON FX890 MASTERPRINT
# 4               4               6                             ACUCAR COMUM
# ...           ...             ...                                      ...
# 34583       37519           38223            MARC PERM RECAR PT BRW CA7002
# 34584       37520           38224            MARC PERM RECAR VM BRW CA7003
# 34585       37522           38226  PISTOLA P/APLICAR COLA QUENTE PQ FUTURO
# 34586       37523           38227          PERFURADOR METAL 2F 20FL FUTURO
# 34587       37526           38230   QUENTINHA MANUAL 3DV Y C/100 BRICOFLEX
#
# ...
